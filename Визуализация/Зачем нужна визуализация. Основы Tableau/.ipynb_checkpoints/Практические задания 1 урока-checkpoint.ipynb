# %% [markdown]
# ## 1. Визуализация данных нужна, чтобы:
#
# * **быстрее и удобнее находить ответы на некоторые вопросы**
# * дашборды были красивыми
# * убрать все таблицы из дашбордов
# * **нагляднее показывать структуру и особенности данных**
#
#
# ## 2. Bar chart хорошо решает следующую задачу:
#
# * Узнать точное число для точки
# * **Сравнить несколько категорий между собой**
# * Понять кластеры данных
# * Увидеть среднее значение
#
#
# ## 3. Scatter plot хорошо решает задачу/задачи:
#
# * **Проанализировать распределение данных по двум переменным**
# * **Найти кластеры по двум переменным**
# * **Увидеть выбросы в данных**
# * **Понять есть ли корреляция между двумя переменными**
#
#
# ## 4. Таблица хорошо решает задачу/задачи:
#
# * Понять есть ли корреляция между двумя переменными
# * Увидеть выбросы в данных
# * **Сравнить несколько разрезов по разным метрикам**
# * **Узнать точное значение данных**
#
#
# ## 5. Добавление непрерывной переменной (зелёной «пилюли») в область создания визуализации может привести к:
#
# * **созданию оси Y**
# * **созданию оси X**
# * **изменению цвета точки на графике**
# * **изменению размера точки на графике**
# * **созданию непрерывной цветовой шкалы**
#
# ## 6. Какие характеристики визуального элемента точки (Marks) в Табло могут зависеть от данных:
#
# * **Цвет**
# * **Подпись точки**
# * Скорость анимации
# * Толщина обводки
# * **Размер**
# * **Форма**
# * **Всплывающая подсказка**
# * Цвет обводки
# * Прозрачность
#
# ## 7. Какой график получится, если разместить в области визуализации «пилюли», как на картинке?
# ![](https://storage.yandexcloud.net/klms-public/production/learning-content/11/80/635/1831/8824/image_0jwEYNQ.png)
#
# * График взаимодействия продаж по регионам
# * **Скатерплот с цветными точками**
# * **Точечный график корреляции прибыли на сделку от размера сделки**
# * Линейный график продаж графика
# * Столбчатый график количества сделок по типу продуктов
# * **График, где по оси X отложена сумма продаж по заказу, по оси Y прибыль полученную с заказа, а цветом точки обозначен регион продажи**
#
#
# ## 8. На картинке ниже — график. Какому набору «пилюль» в области визуализации он соответствует?
# ![](https://storage.yandexcloud.net/klms-public/production/learning-content/11/80/635/1831/8825/Q8.jpg)
#
# * 1
# * 2
# * **3**
# * 4
#
#
# ## 9. На картинке ниже «пилюли» в области визуализации. Какие значения будут на оси X и Y для точек на графике?
# ![](https://storage.yandexcloud.net/klms-public/production/learning-content/11/80/635/1831/8826/image_vh0n6c5.png)
#
# * Две точки: [x:145456, y:6939] [x:122491, y:22906]
# * **Три точки: [x:3.76, y:25.02] [x:3.78, y:7.77] [x:3.80, y:6.88]**
# * Три точки: [x:145456, y:6939] [x:122491, y:22906] [x:18451, y:8028]
# * Две точки: [x:6.76, y:25.02] [x:5.78, y:7.37]
#
#
# ## 10. Какое сочетание пилюль позволит построить график изменения продаж во времени?
# ![](https://storage.yandexcloud.net/klms-public/production/learning-content/11/80/635/1831/8827/image.png)
#
# * 1
# * 2
# * 3
# * **4**
#
#
# ## Дополнительные материалы по Tableau:
#
# 1. [Как сделать донат чарт](https://kb.tableau.com/articles/issue/creating-donut-charts)
# 2. [Поддержка Tableau](https://www.tableau.com/support/help)
# 3. [Бесплатное официальное обучение по Tableau](https://www.tableau.com/learn)
# 4. [Виды визуализаций (datavizproject)](https://datavizproject.com/)
# 5. [Виды визуализаций (Tableau)](https://public.tableau.com/en-us/gallery/visual-vocabulary)
# 6. [Вебинар про Таблицы vs Графики](https://www.youtube.com/watch?v=VV3N0RmDbdE%C2%A0%C2%A0)
