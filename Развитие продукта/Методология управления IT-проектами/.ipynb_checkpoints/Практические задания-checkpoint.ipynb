# %% [markdown]
# ## 1. Отметьте ключевые фазы любого проекта:
#
# * **Контроль**
# * **Исполнение**
# * **Инициация**
# * **Планирование**
# * Делегирование
# * **Завершение**
# * Подведение итогов
# * Ретроспектива
#
# ## 2. Сколько ценностей у философии Agile?
#
# * 5
# * 12
# * 11
# * **4**
#
# ## 3. Что из перечисленного не является обязательным событием Скрама:
#
# * Планирование спринта
# * **Планирование релиза**
# * Дейли скрам
# * Ретроспектива
#
# ## 4. Какой роли нет в скраме?
#
# * **Product manager**
# * Development team
# * Scrum master
# * Product owner
#
# ## 5. Что не относится к артефактам в Скраме?
#
# * Инкремент
# * Бэклог спринта
# * Продуктовый бэклог
# * **Доска**
#
# ## 6. К какой парадигме относится Канбан?
#
# * **Agile**
# * Спиральной
# * Каскадной
#
# ## 7. Сопоставьте проекты и подходы к их организации, которые подойдут им лучше всего:
#
# `Небольшой проект с четко описанными требованиями` - **Waterfall**
#
# `Объемный проект, у которого нет четкого видения конечного результата` - **Agile**
